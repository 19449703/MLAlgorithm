# %%
import matplotlib.pyplot as plt
import numpy as np
import KdTree
import random

# %reload_ext autoreload
# %autoreload 2

# %%
data = [(2,5), (6,1.4), (3.8,8), (8.5,3), (8,5.5), (1,1), (1.5,8.5)]
target = (2.1, 5.5)

kd = KdTree.KdTree(data, 1)
kd.PlotKdTree2D(target, 0, 10, 0, 10)

# %%
k_list = kd.search_k_nearest(target, 3)
kd.PlotKdTree2DWithKNearest(target, k_list, 0, 10, 0, 10)

# %%
xmax = 25
ymax = 15
data = [(random.uniform(1, xmax), random.uniform(1, ymax)) for i in range(40)]
target = (random.uniform(1, xmax), random.uniform(1, ymax))

kd = KdTree.KdTree(data, 1)
kd.PlotKdTree2D(target, 0, xmax, 0, ymax, plotCoord=False)

# %%
k_list = kd.search_k_nearest(target, 5)
kd.PlotKdTree2DWithKNearest(target, k_list, 0, xmax, 0, ymax, plotCoord=False)

# %%
xmax = 10
ymax = 10
zmax = 10
random.seed(100)
data = [(random.uniform(1, xmax), random.uniform(1, ymax), random.uniform(1, zmax)) for i in range(4)]
target = (random.uniform(1, xmax), random.uniform(1, ymax), random.uniform(1, zmax))

kd = KdTree.KdTree(data, 0)
kd.PlotKdTree3D(target, 0, xmax, 0, ymax, 0, zmax)
# Out:
# <div id='636e439f-63e9-4718-93e7-73ee3aa5e568'></div>
